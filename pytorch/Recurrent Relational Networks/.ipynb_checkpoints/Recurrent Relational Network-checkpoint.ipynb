# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Original paper: https://arxiv.org/abs/1711.08028
#
#
# This notebook will show the example of how to solve a Sudoku puzzle with a recurrent relational network.
#
# x is the input feature vector. <br>
# h is the hidden state of the node.<br>
# o is the output.<br>
# m is the the message between the nodes which can be modeled with an MLP.<br>
#
# Input vector x could also be modeled with an MLP based on the input(cell value, row and column).<br>
# Each cell in the sudoku grid is considered a node in the graph.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import torch
import torch.nn.functional as F

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We accept the messages from all connected nodes and sum them before passing it to the recurrent layer.<br>
# Seems like there have to be 81 recurrent nodes for each cell that takes input from every cell that is connected to it(block, row, column).
#
# Thus, the overall structure would be:
#
# RNN node(representing a cell of the sudoku grid(graph)) is connected to other RNN nodes that are in the grid in the same box, row and column.
#
# Sort of like this (Source: Aalto University)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We will need to construct classes to represent each cell as RNNs<br>
# Input vector as a tensor of embeddings (digit, row, column) modeled with MLP.<br>
# Message passing as MLP<br>
# And the output as MLP<br>

# %%
#to pass messages between nodes
class MessagePasser(torch.nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.relu = torch.nn.ReLU()
        self.linear = torch.nn.Linear(in_dim, out_dim)
        
    def forward(self, x):
        x = F.relu(self.linear(x))
        #x = F.relu(torch.nn.Linear(48, 96)(x))
        x = F.relu(torch.nn.Linear(96, 96)(x))
        x = F.relu(torch.nn.Linear(96, 96)(x))
        x = torch.nn.Linear(96,96)(x)
        return x

# %%
#to model the message passing and feature vector(x_i) generation
class InMLP(torch.nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.relu = torch.nn.ReLU()
        self.linear = torch.nn.Linear(in_dim, out_dim)
        
    def forward(self, x):
        x = F.relu(self.linear(x))
        #x = F.relu(torch.nn.Linear(48, 96)(x))
        x = F.relu(torch.nn.Linear(96, 96)(x))
        x = F.relu(torch.nn.Linear(96, 96)(x))
        x = torch.nn.Linear(96,96)(x)
        return x

# %%
#to model the message passing and feature vector(o_i) generation
class OutMLP(torch.nn.Module):
    def __init__(self, in_dim, out_dim): #in_dim=32, out_dim=9
        super().__init__()
        self.relu = torch.nn.ReLU()
        self.linear = torch.nn.Linear(in_dim, out_dim)
        
    def forward(self, x):
        x = F.relu(self.linear(x))
        x = F.relu(torch.nn.Linear())
        x = self.linear(x)
        return x

# %%
#to model the nodes
#accepts inputs from the cell (d, row, col) and the sum of messages from other nodes.
class LSTM(torch.nn.Module):
    def __init__(self, in_dim, hid_dim, n_layers): #in_dim=96 , hid_dim=32 (same used in bAbI), n_layers=1
        super().__init__()
        self.lstm = torch.nn.LSTM(in_dim, hid_dim, n_layers)
        
    def forward(self,x, h):
        x = self.lstm(x, h)
        return x
    
    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        hidden = (weight.new(self.n_layers, batch_size, self.hid_dim).zero_().to(device),
                      weight.new(self.n_layers, batch_size, self.hid_dim).zero_().to(device))
        return hidden

# %%
def preprocess(d, row, col):
    emb_d = torch.nn.Embedding(16,16)
    emb_row = torch.nn.Embedding(16,16)
    emb_col = torch.nn.Embedding(16,16)
    
    x = torch.cat((emb_d(d), emb_row(row), emb_col(col)))
    net = InMLP(48,96)
    x = net(x.flatten())
    return x, net

# %%
x, net = preprocess(torch.tensor([3]),torch.tensor([3]),torch.tensor([3]))
print(x)
print(net)
# Out:
# tensor([ 2.7750e-01,  1.0491e+00, -1.3678e+00, -2.5899e-01,  8.1340e-01,
#         -7.6282e-01, -5.2294e-01,  9.4355e-01, -4.0130e-02, -1.8793e-01,
#          2.9365e-01,  8.4923e-01, -1.0424e+00,  9.3863e-02, -1.0368e+00,
#         -3.5215e-01,  2.3206e-01, -5.3005e-01,  1.0708e+00,  1.8314e+00,
#         -1.3838e-01, -1.0330e-03,  1.7078e-01, -5.3633e-01, -3.2656e-01,
#          1.1710e+00,  2.8755e-01,  9.4489e-03,  8.1821e-01,  3.5780e-01,
#          1.0696e+00, -8.0348e-01,  6.8669e-01, -1.0829e+00, -1.2657e+00,
#          9.6731e-01,  8.3017e-01, -2.2961e-01, -8.3212e-01, -2.8902e-01,
#          1.3323e+00,  9.3642e-01,  7.4951e-01,  1.8815e+00, -5.2058e-01,
#          7.7603e-02,  6.0791e-01, -8.3076e-01,  2.0323e-01,  3.8496e-01,
#          9.3031e-02,  4.8259e-01,  1.5106e+00, -6.2850e-01,  2.1813e-01,
#          2.0737e-01, -1.1934e+00,  1.0627e+00,  1.6528e-01,  5.3368e-01,
#         -3.5828e-01, -4.2735e-02, -6.1172e-01, -1.4117e+00, -1.8862e-01,
#         -3.5565e-01,  4.1457e-01,  2.0340e-01, -2.7481e-01, -9.4221e-01,
#          8.7537e-01,  5.3042e-01, -9.6537e-02,  4.4137e-01, -1.5979e-01,
#          6.2163e-01,  6.5767e-01, -5.2836e-01,  3.3179e-01,  5.8826e-01,
#          2.9477e-01,  2.7567e-01,  1.0621e+00,  5.7458e-01, -2.0058e-01,
#          1.7910e+00,  3.8490e-01,  1.3700e+00,  6.8241e-01, -4.0068e-01,
#          3.1920e-02, -3.4933e-01,  7.4583e-01,  1.2358e-01,  2.0247e-01,
#          7.0596e-02], grad_fn=<AddBackward0>)
# MLP(
#   (linear): Linear(in_features=48, out_features=96, bias=True)
# )

# %%
#in_tensor = (d, row, col)
class RRN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.lstm = LSTM(96, 32, 1)
        self.out_mlp = OutMLP(32,1)
        
    def preprocess(self, d, row, col):
        emb_d = torch.nn.Embedding(16,16)
        emb_row = torch.nn.Embedding(16,16)
        emb_col = torch.nn.Embedding(16,16)

        x = torch.cat((emb_d(d), emb_row(row), emb_col(col)))
        net = InMLP(48,96)
        x = net(x.flatten())
        return x, net
        
    def forward(self,x): #x - (d, row, col)
        x, net = self.preprocess(*x)
        #add messages and sum them to x
        x = self.lstm(x)
        x = self.out_mlp(x)
        return x
